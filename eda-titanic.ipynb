# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic-dataset/Titanic-Dataset.csv
# /kaggle/input/titanic/train_data.csv
# /kaggle/input/titanic/test_data.csv
# /kaggle/input/apple-quality/apple_quality.csv

# %%
#import libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/kaggle/input/titanic-dataset/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Cleaning and Filtering the Data

# %% [markdown]
# ****

# %%
#find missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
df_clean=df.drop(["PassengerId"],axis=1,inplace=True)
df_clean=df.drop(["Name"],axis=1)
df_clean=df.drop(["Ticket"],axis=1)

# %%
df_clean.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# # One Hot Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex'] = le.fit_transform\
                    (df['Sex'])

df['Embarked'] = le.fit_transform\
                    (df['Embarked'])

# %%
#cleaning Missing values and unnessary columns
df_clean=df

# %%
df_clean
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# 1           1       1    0  38.0      1      0  71.2833         0
# 2           1       3    0  26.0      0      0   7.9250         2
# 3           1       1    0  35.0      1      0  53.1000         2
# 4           0       3    1  35.0      0      0   8.0500         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    1  27.0      0      0  13.0000         2
# 887         1       1    0  19.0      0      0  30.0000         2
# 888         0       3    0   NaN      1      2  23.4500         2
# 889         1       1    1  26.0      0      0  30.0000         0
# 890         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %%
df_clean=df_clean.dropna()

# %%
df_clean.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
#data shape after data cleaning
df_clean.shape
# Out:
# (714, 8)

# %%
df_clean.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# # Finding the Outliers

# %%
sns.boxplot(x="Sex",y="Age",data=df_clean)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#Shape of Outliers
sns.distplot(df_clean["Age"])
# Out:
# /tmp/ipykernel_34/2031013356.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean["Age"])
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#Outliers Removal
df_clean=df_clean[df_clean["Age"]<63]
df_clean.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
df_clean.shape
# Out:
# (699, 8)

# %%
#After Cleaning
sns.boxplot(x="Sex",y="Age",data=df_clean)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df_clean=df_clean[df_clean["Fare"]<63]
df_clean.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2
# 6         0       1    1  54.0      0      0  51.8625         2

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.distplot(df_clean["Fare"])
# Out:
# /tmp/ipykernel_34/3909639883.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean["Fare"])
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# # Histogram For All Columns

# %%
plt.figure(figsize=(40,10))
df_clean.hist()
# Out:
# array([[<Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>,
#         <Axes: title={'center': 'Sex'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>,
#         <Axes: title={'center': 'Embarked'}>, <Axes: >]], dtype=object)

# %%
fig,axes=plt.subplots(2,2,figsize=(20,5))

ax=sns.countplot(x="Survived",data=df_clean,hue="Sex",ax=axes[0,0],palette="cool_r")
for bars in ax.containers:
    ax.bar_label(bars)
ax.set_xticklabels(["Died","Survive"])

ax=sns.countplot(x="Survived",data=df_clean,hue="Pclass",ax=axes[0,1],palette="viridis")
for bars in ax.containers:
    ax.bar_label(bars)
ax.set_xticklabels(["Died","Survive"])


ax=sns.countplot(x="Survived",data=df_clean,hue="SibSp",ax=axes[1,0],palette="cool")
for bars in ax.containers:
    ax.bar_label(bars)
ax.set_xticklabels(["Died","Survive"])


ax=sns.countplot(x="Survived",data=df_clean,hue="Embarked",ax=axes[1,1],palette="cool")
for bars in ax.containers:
    ax.bar_label(bars)
ax.set_xticklabels(["Died","Survive"])
# Out:
# [Text(0, 0, 'Died'), Text(1, 0, 'Survive')]

# %%
df_clean.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.279899 -0.484640 -0.126619 -0.030071  0.089965
# Pclass   -0.279899  1.000000  0.055432 -0.383538  0.124281  0.115031
# Sex      -0.484640  0.055432  1.000000  0.128531 -0.115024 -0.288012
# Age      -0.126619 -0.383538  0.128531  1.000000 -0.362408 -0.218929
# SibSp    -0.030071  0.124281 -0.115024 -0.362408  1.000000  0.403003
# Parch     0.089965  0.115031 -0.288012 -0.218929  0.403003  1.000000
# Fare      0.223315 -0.589153 -0.145955  0.076477  0.399074  0.339037
# Embarked -0.129945  0.088103  0.084091  0.063874  0.033499 -0.008934
#
#               Fare  Embarked
# Survived  0.223315 -0.129945
# Pclass   -0.589153  0.088103
# Sex      -0.145955  0.084091
# Age       0.076477  0.063874
# SibSp     0.399074  0.033499
# Parch     0.339037 -0.008934
# Fare      1.000000 -0.111216
# Embarked -0.111216  1.000000

# %%
corr_df_clean=df_clean.corr()

# %% [markdown]
# # Correlation finding

# %%
sns.heatmap(corr_df_clean)
# Out:
# <Axes: >

# %%
sns.heatmap(corr_df_clean,annot=True)
# Out:
# <Axes: >

# %%
sns.relplot(x="Age",y="Fare",data=df_clean,hue="Sex")
